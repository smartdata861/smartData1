# %% [markdown]
# <a href="https://colab.research.google.com/github/smartdata861/smartData1/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
mydata = pd.read_excel('boolTest.xlsx')
#to read the sheets, that panda converts it to dataframe structure.

# %%
mydata.head(5)
#used to to return the (n) rows.
# Out:
#                                   Test Name  Gender  Age Blood Group Result
# 0                                       TSH  Female   65     Unknown   15.8
# 1                             Free T4 (FT4)  Female   27     Unknown  298.8
# 2                                       TSH  Female   27     Unknown  0.747
# 3                                       TSH    Male   39          O+    100
# 4  ATPO (anti-thyroid peroxidase antibody )  Female   29     Unknown   5.53

# %%
mydata = pd.read_excel('boolTest.xlsx')

# %%
mydata.info()
#prints the info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Test Name    698 non-null    object
#  1   Gender       698 non-null    object
#  2   Age          698 non-null    int64
#  3   Blood Group  698 non-null    object
#  4   Result       698 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 27.4+ KB

# %%
mydata.describe()
#returns description of the data in the dataframe.
# Out:
#               Age
# count  698.000000
# mean    38.057307
# std     16.383571
# min      1.000000
# 25%     27.000000
# 50%     38.000000
# 75%     47.750000
# max     89.000000

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Test Name    698 non-null    object
#  1   Gender       698 non-null    object
#  2   Age          698 non-null    int64
#  3   Blood Group  698 non-null    object
#  4   Result       698 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 27.4+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(40,30))
#creates a histogram bar chart
plt.show()
#display all the active objects

# %%
mydata.hist(['Age'], figsize=(40,30))
plt.show()

# %%
import seaborn as sns
sns.boxplot(x="Gender" , y="Age" , data=mydata)
#used to visualize distribution
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(mydata['Test Name'],mydata['Gender'])
#used to compute a simple cross tabulation of your factors.
# Out:
# Gender                                    Female  Male
# Test Name
#  Free prostate specific antigen ( FPSA)        0     1
#  PTH (parathyroid Hormone )                    1     0
# ATPO (anti-thyroid peroxidase antibody )      22     3
# Alpha fetoprotein (AFP)                        1     0
# Anti-Mullerian Hormone ( AMH )                 1     0
# C-peptide                                      0     1
# CA 125 ( cancer antigen 125 )                  2     0
# CA 19-9 ( carbohydrate antigen 19-9 )          2     1
# Calcitonin (CATN)                              2     0
# Cancer antigen 15-3 (CA 15-3)                  1     0
# Carcinoembryonic antigen (CEA)                 1     1
# Dehydroepiandrosterone sulfate (DHEA-S)        1     0
# Dexamethasone suppression test                 1     0
# E2 (Estradiol)                                 2     0
# FSH(follicle stimulating hormone)              9     0
# Ferritin                                      18     8
# ...

# %%
pd.crosstab(mydata['Blood Group'],mydata['Gender'])
# Out:
# Gender       Female  Male
# Blood Group
# A+               29     8
# A-                1     0
# AB+               9     5
# AB-               1     0
# B+               24     5
# B-                6     1
# O+               44    25
# O-                6     0
# Unknown         398   136

# %%
sns.countplot(x='Gender' , hue='Blood Group' ,data=mydata)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
pd.crosstab(mydata['Age'],mydata['Gender'] )
# Out:
# Gender  Female  Male
# Age
# 1            2     6
# 2            0     2
# 4            0     2
# 6            0     7
# 7            0     3
# ..         ...   ...
# 77           4     0
# 79           0     1
# 80           1     0
# 85           2     0
# 89           3     0
#
# [74 rows x 2 columns]

# %%
pd.pivot_table(mydata, index=['Age', 'Test Name'],
                     columns=[ 'Gender'], aggfunc=len)
# Out:
#                                   Blood Group      Result
# Gender                                 Female Male Female Male
# Age Test Name
# 1   Cancer antigen 15-3 (CA 15-3)         1.0  NaN    1.0  NaN
#     Folate (Folic acid)                   NaN  1.0    NaN  1.0
#     TSH                                   NaN  3.0    NaN  3.0
#     Vitamin B12                           NaN  1.0    NaN  1.0
#     Vitamin D3                            1.0  1.0    1.0  1.0
# ...                                       ...  ...    ...  ...
# 85  Calcitonin (CATN)                     1.0  NaN    1.0  NaN
#     Thyroglobulin                         1.0  NaN    1.0  NaN
# 89  T3                                    1.0  NaN    1.0  NaN
#     T4                                    1.0  NaN    1.0  NaN
#     TSH                                   1.0  NaN    1.0  NaN
#
# [395 rows x 4 columns]

# %%
pd.pivot_table(mydata,'Result', index=['Age', 'Test Name'],
                     columns=[ 'Gender'], aggfunc=len)
# Out:
# Gender                             Female  Male
# Age Test Name
# 1   Cancer antigen 15-3 (CA 15-3)     1.0   NaN
#     Folate (Folic acid)               NaN   1.0
#     TSH                               NaN   3.0
#     Vitamin B12                       NaN   1.0
#     Vitamin D3                        1.0   1.0
# ...                                   ...   ...
# 85  Calcitonin (CATN)                 1.0   NaN
#     Thyroglobulin                     1.0   NaN
# 89  T3                                1.0   NaN
#     T4                                1.0   NaN
#     TSH                               1.0   NaN
#
# [395 rows x 2 columns]

# %%
sns.pairplot(mydata)

# %%
mydata['Age'].std()
# Out:
# 16.383570686238567

# %%
mydata['Age'].mean()
# Out:
# 38.05730659025788

# %%
sns.displot(mydata['Blood Group'])

# %%
mydata.hist(by='Gender',column='Age')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column='Blood Group')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
corr= mydata.corr()
corr
# Out:
#      Age
# Age  1.0

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
